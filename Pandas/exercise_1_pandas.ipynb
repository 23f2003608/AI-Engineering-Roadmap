# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import pandas as pd
a=pd.Series()
a
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
def arithmetic(a,b,c):
  if c=='+':
    return a+b
  elif c=='-':
    return a-b
  elif c=='*':
    return a*b
  elif c=='/':
    return a/b
  else:
    return 'invalid operator'

a=pd.Series([1,2,3,4,5])
b=pd.Series([6,9,10,11,12])
print(arithmetic(a,b,'*'))
# Out:
# 0     6
# 1    18
# 2    30
# 3    44
# 4    60
# dtype: int64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
a=pd.Series([2, 4, 6, 8, 10])
b=pd.Series([1, 3, 5, 7, 10])
print(a==b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
def change_data_type(series,data_type):
  return pd.to_numeric(series,downcast=data_type, errors='coerce')
series = pd.Series([1,2,'Python', 2.0, True, 100])
print(change_data_type(series,'integer'))
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
bat=pd.read_csv('batsman_runs_series.csv', index_col='batter').squeeze()
bat
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %%
#solution
bat.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
bat[bat>3000].count()
# Out:
# np.int64(20)

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
bat[bat>bat.mean()].count()
# Out:
# np.int64(128)

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
#i
import pandas as pd
items = pd.read_csv('items.csv', index_col='item_name').squeeze()
items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
#ii # count() - Ye total rows ka count deta hai (True + False sab)
items.isna().sum()
# Out:
# np.int64(50)

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# i
items = items.str.replace('$', '', regex=False).astype(float)
print(items.mean())
# Out:
# 7.463031496062992

# %%
#ii
items.quantile(.30)
# Out:
# np.float64(4.45)

# %%
#iii
items.plot(kind='hist', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#iv
a = items*83 #convert to dollars
((a >= 1000) & (a <= 2000)).sum()
# Out:
# np.int64(116)
