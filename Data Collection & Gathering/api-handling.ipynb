# %%
import pandas as pd
import requests
import json

# %%
#this API key may have reached it's request limit..you can create your own
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1') #see url end it's fetching page=1
data = response.json()
print(json.dumps(data, indent=4)) #Format this JSON nicely, using 4 spaces for each nested level.
# Out:
# {
#     "page": 1,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg",
#             "genre_ids": [
#                 18,
#                 80
#             ],
#             "id": 278,
#             "original_language": "en",
#             "original_title": "The Shawshank Redemption",
#             "overview": "Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.",
#             "popularity": 29.9525,
#             "poster_path": "/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg",
#             "release_date": "1994-09-23",
#             "title": "The Shawshank Redemption",
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     29.9525
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     28.3701
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     16.0318
# 3  The true story of how businessman Oskar Schind...   1993-12-15     16.1694
# 4  The defense and the prosecution have rested an...   1957-04-10     11.2012
#
#    vote_average  vote_count
# 0         8.715       29646
# 1         8.687       22394
# 2         8.570       13546
# 3         8.566       17068
# 4         8.554        9705

# %%
df = pd.DataFrame() #empty dataframe

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# as 428 were total pages when i was working on this
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True) #deprecated so first make list, append and then use pd.concat

# %%
df
# Out:
#           id                        title  \
# 0      19404  Dilwale Dulhania Le Jayenge
# 1     724089    Gabriel's Inferno Part II
# 2        278     The Shawshank Redemption
# 3        238                The Godfather
# 4     761053   Gabriel's Inferno Part III
# ...      ...                          ...
# 8546   13805               Disaster Movie
# 8547    5491            Battlefield Earth
# 8548   14164         Dragonball Evolution
# 8549   11059            House of the Dead
# 8550   40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1     Professor Gabriel Emerson finally learns the t...   2020-07-31
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4     The final part of the film adaption of the ero...   2020-11-19
# ...

# %%
df.shape
# Out:
# (8551, 7)

# %%
df.to_csv('movies.csv') #to save the dataframe to a csv file
