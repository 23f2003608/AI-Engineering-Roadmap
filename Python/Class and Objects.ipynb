# %%
L = [1,2,3] #object of list class 

L.upper() # append method not defined in the list class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-432573241.py in <cell line: 0>()
#       1 L = [1,2,3] #object of list class
#       2
# ----> 3 L.upper() #not
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = 'hello' # object of string class
s.append('x') # append method not defined in the string class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2296567389.py in <cell line: 0>()
#       1 s = 'hello' # object of string class
# ----> 2 s.append('x') # append method not defined in the string class
#
# AttributeError: 'str' object has no attribute 'append'

# %%
L = [1,2,3]
print(type(L)) # here type is not a method it's a function that any object can call
# Out:
# <class 'list'>

# %%
s = [1,2,3]

# %%
# syntax to create an object

#objectname = classname()

# %%
# object literal
L = [1,2,3]

# %%
L = list()
L
# Out:
# []

# %%
s = str()
s
# Out:
# ''

# %%
# Pascal Case  for Class names, exception names, and type aliases
# snake_case for Function names, method names, variable names, module names, and package names
# pascal Case - HelloWorld
# snake case - hello_world

# %% [markdown]
# ok so class bnta hai do chz se..
# - ek toh data/attributes
# - and dusra hote h methods and functions in that class

# %%
class Atm:

  # constructor(special function)->superpower -> apne app call hoga object initialisation par
  # self is current object
  def __init__(self):
    print(id(self))
    self.pin = '' #initialising the attributes
    self.balance = 0
    # self.menu() #calling menu automatically just after initialisation

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()
#if self not mentioned then function will not work bcoz self is the current object
  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba') # :)
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se..hurr ')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj1 = Atm()
# Out:
# 135147491238896

# %%
id(obj1)
# Out:
# 135147491238896

# %%
obj2 = Atm()
# Out:
# 135147491238704

# %%
id(obj2) # different objects stored at different memory locations
# Out:
# 135147491238704

# %%
L = [1,2,3]
len(L) # function ->bcos it is outside the list class
L.append(6)# method -> bcos it is inside the list class
L
# Out:
# [1, 2, 3, 6]

# %%
class Temp:

  def __init__(self): # Constructor apne ap call hoga object initialisation par
    print('hello')

obj = Temp()
# Out:
# hello

# %%
3/4*1/2
# Out:
# 0.375

# %% [markdown]
# ###  Let's make our own Class for Fractions

# %%
class Fraction:

  # parameterized constructor
  def __init__(self,x,y):
    self.num = x
    self.den = y

# so for magic methods, they are fixed in python..and hum unko khud se call ni kr skte..khud hi invoke honge koi condition match hone pr..like __add__ "+" aane pr khud invoke hoga

  def __str__(self): # object print krne par yhi usko formatted print krega otherwise object with location print hoga 
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):  #addition
    new_num = self.num*other.den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other): #subtraction
    new_num = self.num*other.den - other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other): #multiplication
    new_num = self.num*other.num
    new_den = self.den*other.den

    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other): #division
    new_num = self.num*other.den
    new_den = self.den*other.num

    return '{}/{}'.format(new_num,new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)
fr2 = Fraction(1,2)
print(fr1,fr2)
# Out:
# 3/4 1/2

# %%
fr1.convert_to_decimal()
# 3/4
# Out:
# 0.75

# %%
print(fr1 + fr2)
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 10/8
# 2/8
# 3/8
# 6/4

# %%
s1={1,2,3} #bcoz set class mein __add__ defined hi nahi kiya gya h
s2={3,4,5}

s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4167151565.py in <cell line: 0>()
#       2 s2={3,4,5}
#       3
# ----> 4 s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
print(fr1 - fr2)
# Out:
# 2/8
